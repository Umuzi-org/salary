# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import iqr
import pylab as py
import scipy.stats as pearsonr

# %%
salaryy = pd.read_csv("salary.csv")
salaryy
# Out:
#           salary  exprior  yearsworked  yearsrank  market  degree  otherqual  \
# 0    53000.00000        0            0          0    1.17       1          0
# 1    58000.00000        1            0          0    1.24       1          0
# 2    45500.00000        0            0          0    1.21       1          0
# 3    35782.00000        0            2          1    0.99       1          0
# 4    34731.00000        0            2          2    0.91       1          0
# 5    56000.00000        1            0          0    1.19       1          0
# 6    61008.00000        0            2          2    1.33       1          0
# 7    39986.00000        0            2          0    0.99       1          0
# 8    36308.00000        0            2          1    0.85       1          0
# 9    55000.00000        0            0          0    1.23       1          0
# 10   55227.00000        0            3          3    1.23       1          0
# ...

# %% [markdown]
# ## Question 1.
#
# ### (a). number of responders

# %%
len(salaryy)
# Out:
# 514

# %% [markdown]
# ### (b) What is the lowest salary and highest salary in the group?

# %%
# code for highest salary amount will be printed on top
print(max(salaryy["salary"]))

# code for the lowest salary will be printed below
print(min(salaryy["salary"]))
# Out:
# 96156.0
# 29000.0

# %% [markdown]
# ### (c) What is the mean salary for the sample? Include the standard error of the mean.

# %%
# make a numpy array with the mean and your import
sal_mean = np.mean(salaryy["salary"])
sal_mean
# Out:
# 50863.22009783626

# %% [markdown]
# ### (d) What is the standard deviation for the years worked?

# %%
yrs_worked = np.std(salaryy["yearsworked"])
yrs_worked
# Out:
# 9.435503224576884

# %% [markdown]
# ### (e) What is the median salary for the sample?

# %%
# the median will be printed below NB. "nanmedian" is because the sal_median returned "nan" after print
sal_median = np.array(salaryy["salary"])
np.nanmedian(sal_median)
# Out:
# 50096.0

# %% [markdown]
# ### (f) What is the interquartile range for salary in the sample?

# %%
iqr_sal = iqr(salaryy["salary"])
iqr_sal
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-aea7a1c89708> in <module>()
# ----> 1 iqr_sal = iqr(salaryy["salary"])
#       2 iqr_sal
#
# NameError: name 'iqr' is not defined

# %% [markdown]
# ### (h) How many men are there in the sample? How many women are there in the sample? Present this information in a table.

# %%
# Assuming the response if one is male is 1 then
male1 = salaryy[salaryy.male == 1]
print(len(male1))

# Assuming the response if one is female is 0 then
female = salaryy[salaryy.male == 0]
print(len(female))

all(male1 + female)
# Out:
# 386
# 128
# True

# %%
# Assuming the response if one is male is 1 then
male1 = salaryy[salaryy.male == 1]
male1
# Out:
#        salary  exprior  yearsworked  yearsrank  market  degree  otherqual  \
# 0    53000.00        0            0          0    1.17       1          0
# 1    58000.00        1            0          0    1.24       1          0
# 2    45500.00        0            0          0    1.21       1          0
# 3    35782.00        0            2          1    0.99       1          0
# 4    34731.00        0            2          2    0.91       1          0
# 5    56000.00        1            0          0    1.19       1          0
# 6    61008.00        0            2          2    1.33       1          0
# 7    39986.00        0            2          0    0.99       1          0
# 8    36308.00        0            2          1    0.85       1          0
# 9    55000.00        0            0          0    1.23       1          0
# 10   55227.00        0            3          3    1.23       1          0
# 11   55227.00        0            3          3    1.23       1          0
# ...

# %%
# Assuming the response if one is female is 0 then
female = salaryy[salaryy.male == 0]
female
# Out:
#           salary  exprior  yearsworked  yearsrank  market  degree  otherqual  \
# 386  33800.00000        0            0          0    0.84       1          0
# 387  36833.00000        0            1          1    0.84       1          0
# 388  36308.00000        0            1          0    0.87       1          0
# 389  33680.00000        0            2          1    0.92       1          0
# 390  33680.00000        0            2          2    1.02       1          0
# 391  34731.00000        0            1          1    0.85       1          0
# 392  31000.00000        0            3          2    0.79       1          0
# 393  35782.00000        0            2          1    0.92       1          0
# 394  46292.00000        0            2          2    1.14       1          0
# 395  33680.00000        0            1          1    0.88       1          0
# 396  34731.00000        0            2          1    0.95       1          0
# ...

# %% [markdown]
# ### (h) How many women are full professors compared to men?

# %%
#assuming the the highest position (3) is professors then:
female_pos=female[female.position == 3]
len(female_pos)
# Out:
# 19

# %%
#assuming the the highest position (3) is professors then:
male_pos=male1[male1.position == 3]
len(male_pos)
# Out:
# 192

# %% [markdown]
#  ##### the number of male professors are 192 and female are 19

# %% [markdown]
# ### (i) Create a histogram for the variable Salary.

# %%
hist_sal = salaryy.groupby('salary').size() .reset_index(name='count')
salaryy.hist(column = "salary",)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3a193edb00>]],
#       dtype=object)

# %% [markdown]
# ### (j) Examine the histogram and describe the distribution for Salary.
# #### - The graph above is right-cewed destributed
# #### - There is a large number of people who on from the right are earning less as compared to the ones earning more going to the right

# %% [markdown]
# ### (k) Create a bar graph to show the different average salaries of men and women. (Bonus: Add error bars to the bars showing the 95% confidence interval). What does the graph tell you about the difference between men and women’s salaries?

# %%
female_sal = np.mean(female["salary"])
print('Female average  salaries is       42916.60479734375')

male_sal = np.mean(male1["salary"])
print('Male average salaries is        53505.21167825973' )

# let's create a standard diviation for males and females

#males
std_male = np.std(male1["salary"])
print('Male std is                    12582.930827394985')

#females
std_female = np.std(female["salary"])
print("Female std is                9125.751881437149")

#let's plot the bar

labels = ['Males', 'Females']
counts = [male_sal, female_sal]
error = [std_male,std_female]
plt.bar(labels,counts, yerr=error)
plt.show()
# Out:
# Female average  salaries is       42916.60479734375
# Male average salaries is        53505.21167825973
# Male std is                    12582.930827394985
# Female std is                9125.751881437149

# %% [markdown]
# ### t

# %% [markdown]
# ### (l) Create a scatterplot showing the relationship between Years Worked and Salary (don’t forget to insert a trend line). What is the relationship between Years Worked and Salary?

# %%
y1 = salaryy['salary']
x1 = salaryy['yearsworked']

plt.title("The relationship between Salaries and Work Experience")
plt.xlabel('Years Worked')
plt.ylabel('Amount Earning')
plt.scatter(x1,y1)
z = np.polyfit(x1, y1, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")

plt.show()

# %% [markdown]
# #### (1) Describe any patterns in the scatterplot.
# ##### - the the is one who is getting a lot more but has much less time working there. the difference qould be that the highest paid is the manager or has a higher position in the company (CEO) or (GM)

# %% [markdown]
# ### (m) Using the pearsonr function from the scipy.stats package, calculate the Pearson correlation coefficient (and its corresponding p value) to determine the nature of the relationship between Years Worked and Salary. See help(pearsonr) for help on this function.
